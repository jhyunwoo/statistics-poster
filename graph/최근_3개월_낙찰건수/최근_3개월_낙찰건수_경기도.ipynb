# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
최근3개월_경매건수 = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_경기도.csv",encoding='cp949')
최근3개월_경매건수
# Out:
#    수원장안구  수원권선구  수원팔달구  수원영통구  성남수정구  성남중원구  성남분당구  의정부시  안양만안구  안양동안구  ...  \
# 0     10     28     18      4    3.0    2.0      9    19      8      4  ...
# 1      9     29     16      6    4.0    3.0      7    16     11      7  ...
# 2      7     29      3      4    5.0    2.0      6    14     11      9  ...
# 3      7     12     11      5    3.0    2.0      4    14      9      8  ...
# 4      6     18      8      4    3.0    1.0      4    10      4      5  ...
# 5      7     14     11      3    1.0    NaN      4    13      4      4  ...
# 6     12     24      7      7    2.0    1.0      6    16      5      2  ...
# 7     16     17     11      8    1.0    3.0      5    25      6      2  ...
# 8     17     29     12     11    1.0    3.0      5    29      5      1  ...
# 9     14     44     16     12    NaN    3.0      4    33      3      2  ...
#
#    안성시  김포시  화성시  광주시  양주시  포천시  여주시  연천군  가평군  양평군
# 0   17   23   23   68    7   12   12  1.0   12   24
# 1   11   23   27   61    4   13   14  2.0    9   24
# 2   26   28   26   51    5   12    9  3.0    8   25
# 3   78   22   34   47    6    7   13  1.0   10   29
# 4   69   24   39   43    6    4   16  1.0    9   31
# 5   55   17   45   53   11    5   17  1.0    7   22
# 6   19   16   43   46   18   40   16  1.0    5   11
# 7   11   19   37   50   18    9   15  NaN   35   10
# 8   48   22   42   38   10   14   23  1.0   37   13
# 9   69   26   56   36   12   14   19  1.0   36   14
#
# [10 rows x 42 columns]

# %%
최근3개월_경매건수.index=index

# %%
최근3개월_경매건수
# Out:
#            수원장안구  수원권선구  수원팔달구  수원영통구  성남수정구  성남중원구  성남분당구  의정부시  안양만안구  \
# 2022년 8월      10     28     18      4    3.0    2.0      9    19      8
# 2022년 9월       9     29     16      6    4.0    3.0      7    16     11
# 2022년 10월      7     29      3      4    5.0    2.0      6    14     11
# 2022년 11월      7     12     11      5    3.0    2.0      4    14      9
# 2022년 12월      6     18      8      4    3.0    1.0      4    10      4
# 2023년 1월       7     14     11      3    1.0    NaN      4    13      4
# 2023년 2월      12     24      7      7    2.0    1.0      6    16      5
# 2023년 3월      16     17     11      8    1.0    3.0      5    25      6
# 2023년 4월      17     29     12     11    1.0    3.0      5    29      5
# 2023년 5월      14     44     16     12    NaN    3.0      4    33      3
#
#            안양동안구  ...  안성시  김포시  화성시  광주시  양주시  포천시  여주시  연천군  가평군  양평군
# 2022년 8월       4  ...   17   23   23   68    7   12   12  1.0   12   24
# 2022년 9월       7  ...   11   23   27   61    4   13   14  2.0    9   24
# 2022년 10월      9  ...   26   28   26   51    5   12    9  3.0    8   25
# 2022년 11월      8  ...   78   22   34   47    6    7   13  1.0   10   29
# 2022년 12월      5  ...   69   24   39   43    6    4   16  1.0    9   31
# 2023년 1월       4  ...   55   17   45   53   11    5   17  1.0    7   22
# 2023년 2월       2  ...   19   16   43   46   18   40   16  1.0    5   11
# 2023년 3월       2  ...   11   19   37   50   18    9   15  NaN   35   10
# 2023년 4월       1  ...   48   22   42   38   10   14   23  1.0   37   13
# 2023년 5월       2  ...   69   26   56   36   12   14   19  1.0   36   14
#
# [10 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
최근3개월_경매건수.columns
# Out:
# Index(['수원장안구', '수원권선구', '수원팔달구', '수원영통구', '성남수정구', '성남중원구', '성남분당구', '의정부시',
#        '안양만안구', '안양동안구', '부천시', '광명시', '평택시', '동두천시', '안산상록구', '안산단원구',
#        '고양덕양구', '고양일산동구', '고양일산서구', '과천시', '구리시', '남양주시', '오산시', '시흥시', '군포시',
#        '의왕시', '하남시', '용인처인구', '용인기흥구', '용인수지구', '파주시', '이천시', '안성시', '김포시',
#        '화성시', '광주시', '양주시', '포천시', '여주시', '연천군', '가평군', '양평군'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 15))

for i in 최근3개월_경매건수.columns:
    plt.plot(최근3개월_경매건수[i], label=i)

plt.title('경기도 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
