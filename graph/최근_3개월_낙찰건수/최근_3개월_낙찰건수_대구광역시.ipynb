# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
csv_data = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_대구광역시.csv",encoding='cp949')

# %%
csv_data.index=index

# %%
csv_data
# Out:
#            중구  동구  서구  남구  북구  수성구  달서구  달성군  군위군
# 2022년 8월    3  23   7  10  27   12   16   22  2.0
# 2022년 9월    3  25   7  13  34   11   16   16  2.0
# 2022년 10월   3  28   5  10  30    9   20   13  1.0
# 2022년 11월   1  18   5   8  29   13   24    8  1.0
# 2022년 12월   2  13   7   5  24   15   18   10  NaN
# 2023년 1월    3  14   6   6  25   16   17   15  NaN
# 2023년 2월    4  17   9   8  30   12   20   21  NaN
# 2023년 3월    4  23   8   7  31   17   16   17  NaN
# 2023년 4월   11  27  10   9  35   25   15   16  NaN
# 2023년 5월   14  28   8   6  35   25   15   15  NaN

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
csv_data.columns
# Out:
# Index(['중구', '동구', '서구', '남구', '북구', '수성구', '달서구', '달성군', '군위군'], dtype='object')

# %%
plt.figure(figsize=(15, 10))

for i in csv_data.columns:
    plt.plot(csv_data[i], label=i)

plt.title('대구광역시 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
