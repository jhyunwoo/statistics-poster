# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
csv_data = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_경상남도.csv",encoding='cp949')

# %%
csv_data.index=index

# %%
csv_data
# Out:
#            창원의창구  창원성산구  창원마산합포구  창원마산회원구  창원진해구  진주시  통영시  사천시  김해시  밀양시  \
# 2022년 8월      15     12       21       29     13   68   22   21   64   14
# 2022년 9월      21      7       18       27     14   60   23   21   59   20
# 2022년 10월     15      9       10       26     14   58   27   24   46   18
# 2022년 11월     15      7       11       25     16   44   23   22   42   14
# 2022년 12월     18     10       12       12     13   45   29   25   38    7
# 2023년 1월      20      7       16       10     23   48   23   19   33    5
# 2023년 2월      20     10       13       10     28   56   26   15   41    5
# 2023년 3월      18     12       18       18     28   41   22   18   49    8
# 2023년 4월      24     16       18       20     21   33   22   20   58   11
# 2023년 5월      21     14       15       23     13   24   20   22   55    9
#
#            ...  의령군  함안군  창녕군  고성군  남해군  하동군  산청군  함양군  거창군   합천군
# 2022년 8월   ...  NaN   15    9    8  1.0  1.0  2.0  5.0  3.0  10.0
# 2022년 9월   ...  NaN    9   11    9  NaN  1.0  2.0  5.0  2.0   5.0
# 2022년 10월  ...  NaN    8   12    8  NaN  1.0  NaN  2.0  6.0   3.0
# 2022년 11월  ...  NaN    5    9    9  1.0  NaN  NaN  NaN  5.0   2.0
# 2022년 12월  ...  1.0    7    7    9  2.0  1.0  NaN  NaN  4.0   NaN
# 2023년 1월   ...  1.0    7    6    5  3.0  2.0  NaN  5.0  NaN   NaN
# 2023년 2월   ...  1.0    7    6    4  3.0  2.0  2.0  4.0  4.0   2.0
# 2023년 3월   ...  NaN    6    6    5  4.0  2.0  1.0  5.0  6.0   4.0
# 2023년 4월   ...  NaN    4    8    4  5.0  2.0  2.0  2.0  5.0   6.0
# 2023년 5월   ...  1.0    5    6    6  4.0  2.0  2.0  2.0  2.0   3.0
#
# [10 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
csv_data.columns
# Out:
# Index(['창원의창구', '창원성산구', '창원마산합포구', '창원마산회원구', '창원진해구', '진주시', '통영시', '사천시',
#        '김해시', '밀양시', '거제시', '양산시', '의령군', '함안군', '창녕군', '고성군', '남해군', '하동군',
#        '산청군', '함양군', '거창군', '합천군'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))

for i in csv_data.columns:
    plt.plot(csv_data[i], label=i)

plt.title('경상남도 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
