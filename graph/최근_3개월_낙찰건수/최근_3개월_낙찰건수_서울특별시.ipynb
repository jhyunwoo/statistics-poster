# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
최근3개월_경매건수 = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_서울특별시.csv",encoding='cp949')
최근3개월_경매건수
# Out:
#    종로구  중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  ...  강서구  구로구  금천구  영등포구  \
# 0    2   1    4  NaN    4     5   12   18   32   16  ...   72   14   27    11
# 1    4   2    5  NaN    5     5   10   15   23   17  ...   59   16   17     7
# 2    6   2    3  1.0    6     3   12   11   16   11  ...   66   13   15     4
# 3   14   6    4  3.0    5     2   15   12    8   11  ...   47   12   14     1
# 4   13   5    2  3.0    3     1   14   10    8    9  ...   55   11   19     4
# 5   10   7    5  3.0    3     1   10   11    9   13  ...   58   17   21     7
# 6    7   5    5  3.0    5     1    9    9   12   18  ...   57   21   18     8
# 7    6   4    6  3.0    7     4    9    9   21   19  ...   45   22   14     6
# 8    9   5    4  1.0    7     6   13    8   25   18  ...   40   16   13     2
# 9    8   6    5  1.0    6     7   12    6   25   13  ...   51   15   17     4
#
#    동작구  관악구  서초구  강남구  송파구  강동구
# 0   16   23   14    4    6    6
# 1   24   27   11    7    4    6
# 2   27   28   11   12    6    7
# 3   29   38   12   14    8    7
# 4   21   39   14   12    6   11
# 5   18   37   10   14    4   10
# 6   25   28   13   20    4   11
# 7   31   34   20   24    5   10
# 8   30   26   19   22    8   12
# 9   26   30   16   17    9   14
#
# [10 rows x 25 columns]

# %%
최근3개월_경매건수.index=index

# %%
최근3개월_경매건수
# Out:
#            종로구  중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  ...  강서구  구로구  \
# 2022년 8월     2   1    4  NaN    4     5   12   18   32   16  ...   72   14
# 2022년 9월     4   2    5  NaN    5     5   10   15   23   17  ...   59   16
# 2022년 10월    6   2    3  1.0    6     3   12   11   16   11  ...   66   13
# 2022년 11월   14   6    4  3.0    5     2   15   12    8   11  ...   47   12
# 2022년 12월   13   5    2  3.0    3     1   14   10    8    9  ...   55   11
# 2023년 1월    10   7    5  3.0    3     1   10   11    9   13  ...   58   17
# 2023년 2월     7   5    5  3.0    5     1    9    9   12   18  ...   57   21
# 2023년 3월     6   4    6  3.0    7     4    9    9   21   19  ...   45   22
# 2023년 4월     9   5    4  1.0    7     6   13    8   25   18  ...   40   16
# 2023년 5월     8   6    5  1.0    6     7   12    6   25   13  ...   51   15
#
#            금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구
# 2022년 8월    27    11   16   23   14    4    6    6
# 2022년 9월    17     7   24   27   11    7    4    6
# 2022년 10월   15     4   27   28   11   12    6    7
# 2022년 11월   14     1   29   38   12   14    8    7
# 2022년 12월   19     4   21   39   14   12    6   11
# 2023년 1월    21     7   18   37   10   14    4   10
# 2023년 2월    18     8   25   28   13   20    4   11
# 2023년 3월    14     6   31   34   20   24    5   10
# 2023년 4월    13     2   30   26   19   22    8   12
# 2023년 5월    17     4   26   30   16   17    9   14
#
# [10 rows x 25 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
최근3개월_경매건수.columns
# Out:
# Index(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구',
#        '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구',
#        '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 15))

for i in 최근3개월_경매건수.columns:
    plt.plot(최근3개월_경매건수[i], label=i)

plt.title('서울특별시 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend()
plt.show()
