# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
최근3개월_경매건수 = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_강원특별자치시.csv",encoding='cp949')
최근3개월_경매건수
# Out:
#    춘천시  원주시  강릉시  동해시   태백시  속초시  삼척시  홍천군  횡성군  영월군  평창군  정선군  철원군  화천군  \
# 0   19   17   16   11   2.0    4    6    8  NaN    3    2    5  1.0  1.0
# 1   17   24   14   11   NaN    3    3    7  1.0    4    3    2  1.0  1.0
# 2   20   31    8   12   NaN    3    3    5  2.0    4    6    3  1.0  2.0
# 3   18   28   10   13  17.0    4    1    4  1.0    4    8    2  1.0  1.0
# 4   14   27    9   18  17.0    5    2    7  2.0    5    5    2  2.0  1.0
# 5   18   24   11   11  17.0    6    1    8  1.0    5    3    2  2.0  NaN
# 6   25   25    8   12   NaN    4    2    8  3.0    3    4    3  1.0  NaN
# 7   27   21    8    5   1.0    3    3    5  2.0    1    5    2  NaN  NaN
# 8   23   15    9   11   1.0    1    3    6  4.0    1    7    4  NaN  NaN
# 9   17    9   18    9  30.0    4    6    7  3.0    1    6    2  NaN  NaN
#
#     양구군  인제군  고성군  양양군
# 0   1.0    3  5.0  3.0
# 1   1.0    3  4.0  2.0
# 2   3.0    1  4.0  1.0
# 3   4.0    2  4.0  3.0
# 4  13.0    3  3.0  3.0
# ...

# %%
최근3개월_경매건수.index=index

# %%
최근3개월_경매건수
# Out:
#            춘천시  원주시  강릉시  동해시   태백시  속초시  삼척시  홍천군  횡성군  영월군  평창군  정선군  철원군  \
# 2022년 8월    19   17   16   11   2.0    4    6    8  NaN    3    2    5  1.0
# 2022년 9월    17   24   14   11   NaN    3    3    7  1.0    4    3    2  1.0
# 2022년 10월   20   31    8   12   NaN    3    3    5  2.0    4    6    3  1.0
# 2022년 11월   18   28   10   13  17.0    4    1    4  1.0    4    8    2  1.0
# 2022년 12월   14   27    9   18  17.0    5    2    7  2.0    5    5    2  2.0
# 2023년 1월    18   24   11   11  17.0    6    1    8  1.0    5    3    2  2.0
# 2023년 2월    25   25    8   12   NaN    4    2    8  3.0    3    4    3  1.0
# 2023년 3월    27   21    8    5   1.0    3    3    5  2.0    1    5    2  NaN
# 2023년 4월    23   15    9   11   1.0    1    3    6  4.0    1    7    4  NaN
# 2023년 5월    17    9   18    9  30.0    4    6    7  3.0    1    6    2  NaN
#
#            화천군   양구군  인제군  고성군  양양군
# 2022년 8월   1.0   1.0    3  5.0  3.0
# 2022년 9월   1.0   1.0    3  4.0  2.0
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
최근3개월_경매건수.columns
# Out:
# Index(['춘천시', '원주시', '강릉시', '동해시', '태백시', '속초시', '삼척시', '홍천군', '횡성군', '영월군',
#        '평창군', '정선군', '철원군', '화천군', '양구군', '인제군', '고성군', '양양군'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))

for i in 최근3개월_경매건수.columns:
    plt.plot(최근3개월_경매건수[i], label=i)

plt.title('강원특별자치시 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
