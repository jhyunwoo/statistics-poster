# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
최근3개월_경매건수 = pd.read_csv("../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_전국.csv",encoding='cp949')
최근3개월_경매건수
# Out:
#      전국   수도권    지방
# 0  3688  1371  2317
# 1  3523  1263  2260
# 2  3408  1206  2202
# 3  3321  1220  2101
# 4  3193  1211  1982
# 5  3246  1230  2016
# 6  3218  1239  1979
# 7  3635  1388  2247
# 8  3928  1539  2389
# 9  4178  1600  2578

# %%
최근3개월_경매건수.index=index

# %%
최근3개월_경매건수
# Out:
#              전국   수도권    지방
# 2022년 8월   3688  1371  2317
# 2022년 9월   3523  1263  2260
# 2022년 10월  3408  1206  2202
# 2022년 11월  3321  1220  2101
# 2022년 12월  3193  1211  1982
# 2023년 1월   3246  1230  2016
# 2023년 2월   3218  1239  1979
# 2023년 3월   3635  1388  2247
# 2023년 4월   3928  1539  2389
# 2023년 5월   4178  1600  2578

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
최근3개월_경매건수.columns
# Out:
# Index(['전국', '수도권', '지방'], dtype='object')

# %%
plt.figure(figsize=(10, 5))

for i in 최근3개월_경매건수.columns:
    plt.plot(최근3개월_경매건수[i], label=i)

plt.title('최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend()
plt.show()
