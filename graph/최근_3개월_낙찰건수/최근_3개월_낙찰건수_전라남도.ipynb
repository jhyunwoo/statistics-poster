# %%
area = "전라남도"

# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
csv_data = pd.read_csv(f"../../data/경매낙찰통계_최근3개월_낙찰건수/경매낙찰통계_최근3개월_낙찰건수_{area}.csv",encoding='cp949')

# %%
csv_data.index=index

# %%
csv_data
# Out:
#            목포시  여수시  순천시  나주시  광양시  담양군  곡성군  구례군  고흥군  보성군  ...  강진군  해남군  \
# 2022년 8월    39    5   11    5   29    4  NaN  3.0    1  3.0  ...    5    4
# 2022년 9월    30   26    9    4   24    4  2.0  2.0    3  2.0  ...    5    5
# 2022년 10월   42    9   10    4   12    3  2.0  3.0    7  2.0  ...    2    4
# 2022년 11월   33    5    9    4    5    1  1.0  1.0    5  NaN  ...    3    4
# 2022년 12월   34    5   12    4    5    1  NaN  1.0    3  NaN  ...    1    3
# 2023년 1월    23    6    8    8    6    2  1.0  NaN    2  NaN  ...    1    4
# 2023년 2월    33   10    9    9    6    2  2.0  NaN    2  NaN  ...    3    2
# 2023년 3월    42   10    9    7   11    2  3.0  1.0    3  3.0  ...    3    3
# 2023년 4월    40    9   10    8   10    2  2.0  1.0    2  4.0  ...    2    9
# 2023년 5월    28    9   11   10   16    5  1.0  1.0    5  4.0  ...    2   24
#
#            영암군  무안군  함평군  영광군  장성군  완도군  진도군  신안군
# 2022년 8월    11   10  NaN  NaN  2.0  NaN    1  5.0
# 2022년 9월     8    8  NaN  NaN  2.0  1.0    1  2.0
# 2022년 10월    8    7  NaN  NaN  1.0  2.0    5  1.0
# 2022년 11월   11    6  NaN  NaN  NaN  5.0    4  NaN
# 2022년 12월    8    5  NaN  NaN  1.0  4.0    4  NaN
# 2023년 1월     9    6  NaN  2.0  1.0  4.0    2  NaN
# 2023년 2월     9    7  NaN  4.0  3.0  5.0    2  NaN
# 2023년 3월    11    7  NaN  5.0  1.0  3.0    2  1.0
# 2023년 4월    10    4  2.0  5.0  2.0  2.0    4  1.0
# 2023년 5월     6    5  2.0  4.0  1.0  6.0    4  1.0
#
# [10 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
csv_data.columns
# Out:
# Index(['목포시', '여수시', '순천시', '나주시', '광양시', '담양군', '곡성군', '구례군', '고흥군', '보성군',
#        '화순군', '장흥군', '강진군', '해남군', '영암군', '무안군', '함평군', '영광군', '장성군', '완도군',
#        '진도군', '신안군'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))

for i in csv_data.columns:
    plt.plot(csv_data[i], label=i)

plt.title(f'{area} 최근 3개월 낙찰건수')
plt.ylabel("낙찰 건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
