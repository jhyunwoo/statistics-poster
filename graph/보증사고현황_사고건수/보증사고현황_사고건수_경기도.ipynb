# %%
area = "경기도"

# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
csv_data = pd.read_csv(f"../../data/보증사고현황_사고건수/보증사고현황_사고건수_{area}.csv",encoding='cp949')

# %%
csv_data.index=index

# %%
csv_data
# Out:
#            수원장안구  수원권선구  수원팔달구  수원영통구  성남수정구  성남중원구  성남분당구  의정부시  안양만안구  \
# 2022년 8월     NaN      1    NaN    NaN    NaN    NaN    NaN     3      9
# 2022년 9월     3.0      2    1.0    NaN    NaN    NaN    1.0     1      1
# 2022년 10월    4.0      6    2.0    2.0    NaN    NaN    NaN     4      7
# 2022년 11월    7.0      6    4.0    5.0    1.0    NaN    1.0     5     11
# 2022년 12월    3.0      7    1.0    4.0    1.0    1.0    3.0    10     14
# 2023년 1월     5.0      9    4.0    1.0    3.0    1.0    1.0    11     14
# 2023년 2월     3.0      9    5.0    2.0    NaN    1.0    1.0     7     11
# 2023년 3월     2.0     11    8.0    3.0    NaN    2.0    1.0    11     10
# 2023년 4월     7.0      4    7.0    3.0    NaN    2.0    2.0    12     12
# 2023년 5월     4.0     10    6.0    7.0    NaN    NaN    5.0    15     17
#
#            안양동안구  ...  안성시  김포시   화성시  광주시  양주시  포천시  여주시  연천군  가평군  양평군
# 2022년 8월     NaN  ...  NaN    3   1.0    1  NaN  NaN  NaN  NaN  NaN  NaN
# 2022년 9월     2.0  ...  NaN   11   NaN    8  NaN  1.0  NaN  NaN  NaN  NaN
# 2022년 10월    1.0  ...  NaN    7   1.0   10  NaN  NaN  NaN  NaN  NaN  NaN
# 2022년 11월    1.0  ...  NaN   13   8.0    9  1.0  NaN  1.0  NaN  1.0  NaN
# 2022년 12월    2.0  ...  NaN   17   7.0   17  1.0  1.0  NaN  NaN  1.0  NaN
# 2023년 1월     3.0  ...  NaN   18   7.0   30  1.0  1.0  1.0  NaN  NaN  NaN
# 2023년 2월     9.0  ...  NaN   24   6.0   15  1.0  NaN  NaN  NaN  NaN  NaN
# 2023년 3월     3.0  ...  1.0   24  11.0   45  1.0  NaN  NaN  NaN  NaN  1.0
# 2023년 4월     2.0  ...  NaN   17   7.0   32  NaN  NaN  NaN  NaN  NaN  1.0
# 2023년 5월     5.0  ...  3.0   19  11.0   30  2.0  3.0  NaN  NaN  NaN  3.0
#
# [10 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family="AppleGothic")

# %%
csv_data.columns
# Out:
# Index(['수원장안구', '수원권선구', '수원팔달구', '수원영통구', '성남수정구', '성남중원구', '성남분당구', '의정부시',
#        '안양만안구', '안양동안구', '부천시', '광명시', '평택시', '동두천시', '안산상록구', '안산단원구',
#        '고양덕양구', '고양일산동구', '고양일산서구', '과천시', '구리시', '남양주시', '오산시', '시흥시', '군포시',
#        '의왕시', '하남시', '용인처인구', '용인기흥구', '용인수지구', '파주시', '이천시', '안성시', '김포시',
#        '화성시', '광주시', '양주시', '포천시', '여주시', '연천군', '가평군', '양평군'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 15))

for i in csv_data.columns:
    plt.plot(csv_data[i], label=i)

plt.title(f'{area} 보증사고현황 - 사고건수')
plt.ylabel("사고건수")
plt.xticks(rotation=30)
plt.legend(loc='upper left')
plt.show()
