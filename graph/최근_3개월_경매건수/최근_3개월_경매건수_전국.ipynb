# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
전세가율_아파트_최근3개월 = pd.read_csv("../../data/경매낙찰통계_최근3개월_경매건수/경매낙찰통계_최근3개월_경매건수_전국.csv")
전세가율_아파트_최근3개월
# Out:
#       전국   수도권    지방
# 0  10526  4248  6278
# 1  10784  4477  6307
# 2  11356  4932  6424
# 3  12075  5493  6582
# 4  12705  5971  6734
# 5  12942  5966  6976
# 6  12590  5775  6815
# 7  13755  6508  7247
# 8  14931  7424  7507
# 9  16387  8138  8249

# %%
전세가율_아파트_최근3개월.index=index

# %%
전세가율_아파트_최근3개월
# Out:
#               전국   수도권    지방
# 2022년 8월   10526  4248  6278
# 2022년 9월   10784  4477  6307
# 2022년 10월  11356  4932  6424
# 2022년 11월  12075  5493  6582
# 2022년 12월  12705  5971  6734
# 2023년 1월   12942  5966  6976
# 2023년 2월   12590  5775  6815
# 2023년 3월   13755  6508  7247
# 2023년 4월   14931  7424  7507
# 2023년 5월   16387  8138  8249

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
plt.figure(figsize=(10, 5))
plt.plot(전세가율_아파트_최근3개월["전국"], label="전국")
plt.plot(전세가율_아파트_최근3개월["수도권"], label="수도권")
plt.plot(전세가율_아파트_최근3개월["지방"], label="지방")
plt.title('최근 3개월 경매건수')
plt.ylabel("경매건수")
plt.xticks(rotation=30)
plt.legend()
plt.show()
