# %%
import pandas as pd

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
len(index)
# Out:
# 10

# %%
최근3개월_경매건수 = pd.read_csv("../../data/경매낙찰통계_최근3개월_경매건수/경매낙찰통계_최근3개월_경매건수_경기도.csv")
최근3개월_경매건수
# Out:
#    수원장안구  수원권선구  수원팔달구  수원영통구  성남수정구  성남중원구  성남분당구  의정부시  안양만안구  안양동안구  ...  \
# 0     22     74     42     16      6      3     16    43     30     16  ...
# 1     21     64     26     19      8      6     15    45     34     24  ...
# 2     22     52     15     19     10      8     14    52     34     28  ...
# 3     27     54     23     18      8      9     12    50     30     24  ...
# 4     29     60     24     17      7      9     11    48     21     14  ...
# 5     28     56     26     20      4      7     14    62     24     12  ...
# 6     29     53     24     25      6     10     14    70     24     10  ...
# 7     40     84     28     32      6     10     13    91     28     13  ...
# 8     49    117     38     37      8      9     12    91     22     11  ...
# 9     53    137     42     42     13      8     15    88     27     14  ...
#
#    안성시  김포시  화성시  광주시  양주시  포천시  여주시  연천군  가평군  양평군
# 0   69   66   65  184   12   26   24    5   33   60
# 1   43   64   82  178   10   26   25    6   32   72
# 2   67   71   86  180   15   27   29    6   61   74
# 3  103   65  114  171   21   18   43    3   58   71
# 4  159   60  128  163   33   14   57    4   89   70
# 5  139   50  128  175   45   16   54    9   85   44
# 6   77   57  117  165   50   83   48   10   85   30
# 7   22   76  132  176   46   35   42   11   87   33
# 8   62   88  156  144   39   39   52    9   63   45
# 9  112  102  168  151   36   37   46   11   64   51
#
# [10 rows x 42 columns]

# %%
최근3개월_경매건수.index=index

# %%
최근3개월_경매건수
# Out:
#            수원장안구  수원권선구  수원팔달구  수원영통구  성남수정구  성남중원구  성남분당구  의정부시  안양만안구  \
# 2022년 8월      22     74     42     16      6      3     16    43     30
# 2022년 9월      21     64     26     19      8      6     15    45     34
# 2022년 10월     22     52     15     19     10      8     14    52     34
# 2022년 11월     27     54     23     18      8      9     12    50     30
# 2022년 12월     29     60     24     17      7      9     11    48     21
# 2023년 1월      28     56     26     20      4      7     14    62     24
# 2023년 2월      29     53     24     25      6     10     14    70     24
# 2023년 3월      40     84     28     32      6     10     13    91     28
# 2023년 4월      49    117     38     37      8      9     12    91     22
# 2023년 5월      53    137     42     42     13      8     15    88     27
#
#            안양동안구  ...  안성시  김포시  화성시  광주시  양주시  포천시  여주시  연천군  가평군  양평군
# 2022년 8월      16  ...   69   66   65  184   12   26   24    5   33   60
# 2022년 9월      24  ...   43   64   82  178   10   26   25    6   32   72
# 2022년 10월     28  ...   67   71   86  180   15   27   29    6   61   74
# 2022년 11월     24  ...  103   65  114  171   21   18   43    3   58   71
# 2022년 12월     14  ...  159   60  128  163   33   14   57    4   89   70
# 2023년 1월      12  ...  139   50  128  175   45   16   54    9   85   44
# 2023년 2월      10  ...   77   57  117  165   50   83   48   10   85   30
# 2023년 3월      13  ...   22   76  132  176   46   35   42   11   87   33
# 2023년 4월      11  ...   62   88  156  144   39   39   52    9   63   45
# 2023년 5월      14  ...  112  102  168  151   36   37   46   11   64   51
#
# [10 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
최근3개월_경매건수.columns
# Out:
# Index(['수원장안구', '수원권선구', '수원팔달구', '수원영통구', '성남수정구', '성남중원구', '성남분당구', '의정부시',
#        '안양만안구', '안양동안구', '부천시', '광명시', '평택시', '동두천시', '안산상록구', '안산단원구',
#        '고양덕양구', '고양일산동구', '고양일산서구', '과천시', '구리시', '남양주시', '오산시', '시흥시', '군포시',
#        '의왕시', '하남시', '용인처인구', '용인기흥구', '용인수지구', '파주시', '이천시', '안성시', '김포시',
#        '화성시', '광주시', '양주시', '포천시', '여주시', '연천군', '가평군', '양평군'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 15))

for i in 최근3개월_경매건수.columns:
    plt.plot(최근3개월_경매건수[i], label=i)

plt.title('경기도 최근 3개월 경매건수')
plt.ylabel("경매건수")
plt.xticks(rotation=30)
plt.legend()
plt.show()
