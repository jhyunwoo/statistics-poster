# %%
area_list = ["전국", "시도별", "강원특별자치도", "경기도", "경상남도", "경상북도", "대구광역시", "대전광역시", "부산광역시", "서울특별시", "세종특별자치시", "울산광역시", "인천광역시", "전라남도", "전라북도", "제주특별자치도", "충청남도", "충청북도"]

# %%
index = ["2022년 8월","2022년 9월","2022년 10월","2022년 11월","2022년 12월","2023년 1월","2023년 2월","2023년 3월","2023년 4월","2023년 5월"]

# %%
data_type="경매낙찰통계_최근3개월_낙찰가율"
title = "경매낙찰통계 - 최근 3개월 낙찰가율"
count = "낙찰가율(%)"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
for i in area_list:
    csv_data = pd.read_csv(f"data/{data_type}/{data_type}_{i}.csv", encoding='cp949')
    csv_data.index=index
    plt.figure(figsize=(15, 12))

    for j in csv_data.columns:
        plt.plot(csv_data[j], label=j, linewidth="4", marker="o")



    plt.title(i+" "+title)
    plt.ylabel(count)
    plt.xticks(rotation=30)
    plt.legend(loc='upper left')
    plt.savefig(f"graph_images/{data_type}/{i}.png", dpi=600)
    plt.show()
